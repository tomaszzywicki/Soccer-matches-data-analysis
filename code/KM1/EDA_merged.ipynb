# %% [markdown]
# # Introduction
# Notebook contains EDA of [Soccer detailed players match data](https://www.kaggle.com/datasets/spicemix/soccer-detailed-players-match-data?resource=download) dataset and is first milestone of clustering project for Introduction to Machine Learning university course

# %% [markdown]
# ## Initial data description
#
#
#
# * details of the match statistics for each player
# * two tables with the same structure - both home and away teams
# * each row represents one player for the given match
# * 127 columns

# %% [markdown]
# ## Data import

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings('ignore')

# %%
home_df = pd.read_csv("../../data/players_home_matches.csv")
away_df = pd.read_csv("../../data/players_away_matches.csv")

# %% [markdown]
# We'll focus on the home matches dataset since both of the tables have similar structure

# %%
df = home_df

# %%
df.head()
# Out:
#    Unnamed: 0  awayScore     awayTeamName awayTeamTacticalSchema  homeScore  \
# 0           0          0           Alavés              (4-1-4-1)          2
# 1           1          0  Atlético Madrid                (4-4-2)          2
# 2           2          0       Real Betis              (3-1-4-2)          1
# 3           3          1    Real Sociedad              (4-2-3-1)          0
# 4           4          2   Rayo Vallecano              (4-2-3-1)          3
#
#     homeTeamName homeTeamTacticalSchema   matchDate  matchWeek  \
# 0  Athletic Club              (4-2-3-1)  2019-09-22          5
# 1  Athletic Club              (4-2-3-1)  2019-03-16         28
# 2  Athletic Club              (4-2-3-1)  2019-01-27         21
# 3  Athletic Club              (4-2-3-1)  2020-12-31         16
# 4  Athletic Club              (4-2-3-1)  2019-04-14         32
#
#         playerName  ...  touches_att_3rd  touches_att_pen_area  \
# 0      Raúl García  ...             28.0                   6.0
# 1   Mikel San José  ...              9.0                   3.0
# 2  Óscar de Marcos  ...             24.0                   6.0
# 3       Unai López  ...              3.0                   1.0
# 4    Iñigo Córdoba  ...             20.0                   3.0
#
#    touches_def_3rd  touches_def_pen_area  touches_live_ball  touches_mid_3rd  \
# 0              2.0                   0.0               50.0             23.0
# 1             10.0                   1.0               49.0             31.0
# 2              3.0                   1.0               32.0              7.0
# 3              3.0                   1.0               11.0              8.0
# 4              8.0                   1.0               43.0             19.0
#
#     xa   xg      team_name  championship_name
# 0  0.1  0.9  Athletic Club               liga
# 1  0.1  0.0  Athletic Club               liga
# 2  0.4  0.1  Athletic Club               liga
# 3  0.0  0.1  Athletic Club               liga
# 4  0.3  0.0  Athletic Club               liga
#
# [5 rows x 127 columns]

# %%
home_df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76215 entries, 0 to 76214
# Data columns (total 127 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    Unnamed: 0                   76215 non-null  int64
#  1    awayScore                    76215 non-null  int64
#  2    awayTeamName                 76215 non-null  object
#  3    awayTeamTacticalSchema       76215 non-null  object
#  4    homeScore                    76215 non-null  int64
#  5    homeTeamName                 76215 non-null  object
#  6    homeTeamTacticalSchema       76215 non-null  object
#  7    matchDate                    76215 non-null  object
#  8    matchWeek                    76215 non-null  int64
#  9    playerName                   76215 non-null  object
#  10   aerials_lost                 76142 non-null  float64
#  11   aerials_won                  76142 non-null  float64
#  12   aerials_won_pct              53345 non-null  float64
#  13   age                          76215 non-null  float64
#  14   assisted_shots               76142 non-null  float64
#  15   assists                      76215 non-null  int64
#  16   ball_recoveries              76142 non-null  float64
#  17   blocked_passes               76142 non-null  float64
#  18   blocked_shots                76142 non-null  float64
#  19   blocked_shots_saves          76142 non-null  float64
#  20   blocks                       76142 non-null  float64
#  21   cards_red                    76215 non-null  int64
#  22   cards_yellow                 76215 non-null  int64
#  23   cards_yellow_red             76215 non-null  int64
#  24   carries                      76142 non-null  float64
#  25   carries_into_final_third     76114 non-null  float64
#  26   carries_into_penalty_area    76114 non-null  float64
#  27   carry_distance               76142 non-null  float64
#  28   carry_progressive_distance   76142 non-null  float64
#  29   clearances                   76142 non-null  float64
#  30   corner_kicks                 76142 non-null  float64
#  31   corner_kicks_in              76142 non-null  float64
#  32   corner_kicks_out             76142 non-null  float64
#  33   corner_kicks_straight        76142 non-null  float64
#  34   crosses                      76215 non-null  int64
#  35   crosses_into_penalty_area    76142 non-null  float64
#  36   dispossessed                 76142 non-null  float64
#  37   dribble_tackles              76142 non-null  float64
#  38   dribble_tackles_pct          42197 non-null  float64
#  39   dribbled_past                76142 non-null  float64
#  40   dribbles                     76142 non-null  float64
#  41   dribbles_completed           76142 non-null  float64
#  42   dribbles_completed_pct       39333 non-null  float64
#  43   dribbles_vs                  76142 non-null  float64
#  44   errors                       76142 non-null  float64
#  45   fouled                       76215 non-null  int64
#  46   fouls                        76215 non-null  int64
#  47   gca                          76142 non-null  float64
#  48   goals                        76215 non-null  int64
#  49   interceptions                76215 non-null  int64
#  50   minutes                      76168 non-null  float64
#  51   miscontrols                  76142 non-null  float64
#  52   npxg                         76142 non-null  float64
#  53   nutmegs                      76142 non-null  float64
#  54   offsides                     76215 non-null  int64
#  55   own_goals                    76215 non-null  int64
#  56   pass_targets                 76142 non-null  float64
#  57   passes                       76142 non-null  float64
#  58   passes_blocked               76142 non-null  float64
#  59   passes_completed             76142 non-null  float64
#  60   passes_completed_long        76142 non-null  float64
#  61   passes_completed_medium      76142 non-null  float64
#  62   passes_completed_short       76142 non-null  float64
#  63   passes_dead                  76142 non-null  float64
#  64   passes_free_kicks            76142 non-null  float64
#  65   passes_ground                76142 non-null  float64
#  66   passes_head                  76142 non-null  float64
#  67   passes_high                  76142 non-null  float64
#  68   passes_intercepted           76142 non-null  float64
#  69   passes_into_final_third      76142 non-null  float64
#  70   passes_into_penalty_area     76142 non-null  float64
#  71   passes_left_foot             76142 non-null  float64
#  72   passes_live                  76142 non-null  float64
#  73   passes_long                  76142 non-null  float64
#  74   passes_low                   76142 non-null  float64
#  75   passes_medium                76142 non-null  float64
#  76   passes_offsides              76142 non-null  float64
#  77   passes_oob                   76142 non-null  float64
#  78   passes_other_body            76142 non-null  float64
#  79   passes_pct                   75408 non-null  float64
#  80   passes_pct_long              66248 non-null  float64
#  81   passes_pct_medium            72790 non-null  float64
#  82   passes_pct_short             73169 non-null  float64
#  83   passes_pressure              76142 non-null  float64
#  84   passes_progressive_distance  76142 non-null  float64
#  85   passes_received              76142 non-null  float64
#  86   passes_received_pct          75511 non-null  float64
#  87   passes_right_foot            76142 non-null  float64
#  88   passes_short                 76142 non-null  float64
#  89   passes_switches              76142 non-null  float64
#  90   passes_total_distance        76142 non-null  float64
#  91   pens_att                     76215 non-null  int64
#  92   pens_conceded                73217 non-null  float64
#  93   pens_made                    76215 non-null  int64
#  94   pens_won                     73217 non-null  float64
#  95   players_dribbled_past        76142 non-null  float64
#  96   pressure_regain_pct          69397 non-null  float64
#  97   pressure_regains             76142 non-null  float64
#  98   pressures                    76142 non-null  float64
#  99   pressures_att_3rd            76142 non-null  float64
#  100  pressures_def_3rd            76142 non-null  float64
#  101  pressures_mid_3rd            76142 non-null  float64
#  102  progressive_carries          76114 non-null  float64
#  103  progressive_passes           76142 non-null  float64
#  104  progressive_passes_received  76142 non-null  float64
#  105  sca                          76142 non-null  float64
#  106  shots_on_target              76215 non-null  int64
#  107  shots_total                  76215 non-null  int64
#  108  tackles                      76142 non-null  float64
#  109  tackles_att_3rd              76142 non-null  float64
#  110  tackles_def_3rd              76142 non-null  float64
#  111  tackles_interceptions        76142 non-null  float64
#  112  tackles_mid_3rd              76142 non-null  float64
#  113  tackles_won                  76215 non-null  int64
#  114  through_balls                76142 non-null  float64
#  115  throw_ins                    76142 non-null  float64
#  116  touches                      76142 non-null  float64
#  117  touches_att_3rd              76142 non-null  float64
#  118  touches_att_pen_area         76142 non-null  float64
#  119  touches_def_3rd              76142 non-null  float64
#  120  touches_def_pen_area         76142 non-null  float64
#  121  touches_live_ball            76142 non-null  float64
#  122  touches_mid_3rd              76142 non-null  float64
#  123  xa                           76142 non-null  float64
#  124  xg                           76142 non-null  float64
#  125  team_name                    76215 non-null  object
#  126  championship_name            75551 non-null  object
# dtypes: float64(99), int64(20), object(8)
# memory usage: 73.8+ MB

# %%
columns = home_df.columns[home_df.isnull().mean() > 0.3]
print(columns)
# Out:
# Index(['aerials_won_pct', 'dribble_tackles_pct', 'dribbles_completed_pct'], dtype='object')

# %%
null_threshold = 0.5
rows_with_nulls  = home_df[home_df.isnull().sum(axis=1) >= null_threshold*len(home_df.columns)]
print(len(rows_with_nulls))
# Out:
# 73

# %%
home_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# We can see that there are some columns with a lot NULL values, and also some rows that doesn't contain much information

# %% [markdown]
# ## Extended data description

# %% [markdown]
# ### Our dataset consists of 117 numeric and 8 non-numeric columns

# %% [markdown]
# ### Non-numeric columns are:
# - championship_name
# - matchDate
# - homeTeamName
# - awayTeamName
# - homeTeamTacticalSchema
# - awayTeamTacticalSchema
# - team_name
# - playerName

# %% [markdown]
# ### The rest of columns which are numeric mostly describe various match statistics for each individual player from the home and away team

# %% [markdown]
# #### We decided to group these columns into a couple of categories:
# - Offensive statistics
#     - goals
#     - assists
#     - shots_total
#     - shots_on_target
#     - xg (oczekiwane gole)
#     - xa (oczekiwane asysty)
#     - gca (wielokrotne zdarzenia przyczyniające się do celnej akcji)
#     - sca (wielokrotne zdarzenia przyczyniające się do strzału)
#     - assisted_shots
#     - carries
#     - carries_into_final_third
#     - carries_into_penalty_area
#     - carry_distance
#     - carry_progressive_distance
#     - progressive_carries
#     - dispossessed
#     - dribble_tackles
#     - dribble_tackles_pct
#     - dribbled_past
#     - errors
#     - miscontrols
#     - own_goals
#     - pens_att
#     - pens_conceded
#     - pens_made
#     - pens_won
#     - players_dribbled_past
#     - through_balls
#     - corner_kicks
#     - corner_kicks_in
#     - corner_kicks_out
#     - corner_kicks_straight
#     - throw_ins
#
# - Defensive statistics
#     - interceptions
#     - tackles
#     - tackles_won
#     - pressure_regains
#     - pressures
#     - ball_recoveries
#     - blocks
#     - blocked_shots
#     - blocked_passes
#     - clearances
#     - tackles_att_3rd
#     - tackles_def_3rd
#     - tackles_interceptions
#     - tackles_mid_3rd
#     - touches_att_3rd
#     - touches_att_pen_area
#     - touches_def_3rd
#     - touches_def_pen_area
#     - touches_live_ball
#     - touches_mid_3rd
#     - pressures_att_3rd
#     - pressures_def_3rd
#     - pressures_mid_3rd
# - Passes statistics
#     - passes
#     - passes_completed
#     - passes_pct (procentowa skuteczność podań)
#     - passes_progressive_distance (odległość postępujących podań)
#     - passes_received (odebrane podania)
#     - passes_received_pct (procentowa skuteczność odebranych podań)
#     - passes_into_final_third
#     - passes_into_penalty_area
#     - progressive_passes (postępujące podania)
#     - progressive_passes_received (odebrane postępujące podania)
#     - passes_blocked
#     - passes_completed_long
#     - passes_completed_medium
#     - passes_completed_short
#     - passes_dead
#     - passes_free_kicks
#     - passes_ground
#     - passes_head
#     - passes_high
#     - passes_intercepted
#     - passes_left_foot
#     - passes_live
#     - passes_long
#     - passes_low
#     - passes_medium
#     - passes_offsides
#     - passes_oob
#     - passes_other_body
#     - passes_pct_long
#     - passes_pct_medium
#     - passes_pct_short
#     - passes_pressure
#     - passes_switches
#     - passes_total_distance
# - Dribble statistics
#     - dribbles
#     - dribbles_completed
#     - dribbles_completed_pct
#     - dribbles_vs
# - Physical stats
#     - aerials_lost
#     - aerials_won
#     - aerials_won_pct
#     - fouled
#     - fouls
#     - nutmegs
#     - offsides
# - Other
#     - age
#     - minutes
#     - matchWeek
#     - homeScore
#     - awayScore

# %% [markdown]
# ## Selecting important columns based on our football knowledge

# %%
important_cols = [
    'goals',
    'assists',
    'shots_total',
    'shots_on_target',
    'xg',
    'xa',
    'gca',
    'carries',
    'dispossessed',
    'dribbled_past',
    'own_goals',
    'pens_made',
    'pens_won',
    'pens_att',
    'players_dribbled_past',
    'through_balls',
    'corner_kicks',
    'throw_ins',
    'interceptions',
    'tackles',
    'pressures',
    'ball_recoveries',
    'blocks',
    'blocked_shots',
    'clearances',
    'passes',
    'passes_progressive_distance',
    'passes_into_final_third',
    'passes_offsides',
    'passes_switches',
    'dribbles',
    'fouled',
    'fouls',
    'offsides',
    'minutes'
]
print(len(important_cols))
# Out:
# 35

# %% [markdown]
# ### Helpful functions to visualize the data

# %%
def plot_integer_hist(df, column, ax):
    bins = np.arange(df[column].min(), df[column].max() + 1.5) - 0.5
    sns.histplot(df[column], bins=bins, ax=ax)

    has_fractional_values = any(df[column] % 1 != 0)
    if not has_fractional_values:
        ax.set_xticks(bins + 0.5)

def plot_float_hist(df, column, ax):
    sns.histplot(df[column], ax=ax)

def create_hist_subplots(df, columns, rows, cols, figsize=(15, 10), title=None):
    fig, axs = plt.subplots(rows, cols, figsize=figsize)
    axs = axs.flatten()
    for i, col in enumerate(columns):
        plot_integer_hist(df, col, axs[i])
    if title:
        plt.suptitle(title, fontsize=20)
    plt.tight_layout()

def create_boxplot_subplots(df, columns, rows, cols, figsize=(15, 10), title=None):
    fig, axs = plt.subplots(rows, cols, figsize=figsize)
    axs = axs.flatten()
    for i, col in enumerate(columns):
        sns.boxplot(x=col, data=df, ax=axs[i])
    if title:
        plt.suptitle(title, fontsize=20)
    plt.tight_layout()

# %%
create_hist_subplots(df, important_cols, 7, 5, figsize=(20, 30))

# %% [markdown]
# As we can see most of the columns have distribution which is similar to **exponential distribution** which is pretty understandable because for example most of the players in a certain match have 0 goals or assists

# %%
create_boxplot_subplots(df, important_cols, 7, 5, figsize=(20, 30))

# %%
corr = df[important_cols].corr()
plt.figure(figsize=(25, 15))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation matrix', fontsize=20)
plt.show()

# %%
mask = abs(corr) < 0.4
plt.figure(figsize=(25, 15))
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1, center=0)
# Out:
# <Axes: >
